# %% [markdown]
# <a href="https://colab.research.google.com/github/JessCosta137/programaria-python/blob/main/Analise_dados_Introdu%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Curso - Análise de Dados com Python
#
# Neste notebook, vamos explorar os dados do formulário da PrograMaria utilizando conceitos de estatística descritiva e a biblioteca **Pandas**. O objetivo principal é realizar a manipulação, limpeza e associação entre variáveis categóricas para identificar possíveis correlações na base de dados.
#
# O **Pandas** é a ferramenta central deste estudo, sendo utilizado para estruturar os dados em DataFrames, criar tabelas cruzadas (`crosstab`) e preparar as matrizes numéricas que alimentam nossos cálculos estatísticos.
#
# **Aluna:** Jéssica da Silva Costa
# **Curso:** Eu Progr{amo} | PrograMaria
#
# ---
#
# ---

# %% [markdown]
# #Uso da biblioteca Pandas

# %%
#Importações:
from google.colab import drive
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_excel("/content/drive/MyDrive/PROGRAMARIA/Cópia de [Copie essa planilha] planilha_modulo2.xlsx")

# %%
dados
# Out:
#                                           ID  IDADE FAIXA IDADE     GENERO  \
# 0        0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1        1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2        2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3        3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4        4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# ...    ...                               ...    ...         ...        ...
# 4266  4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
# ...

# %%
dados.head(10)
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0  0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5  5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# 6  6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7  7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34   Feminino
# 8  8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9  9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# ...

# %%
dados.tail()
# Out:
#                                           ID  IDADE FAIXA IDADE     GENERO  \
# 4266  4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
# 4268  4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4266         Branca  Não                                                NaN
# 4267         Branca  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#       PREJUDICA? ASPECTOS_PREJUDICADOS  ...  \
# ...

# %%
dados.shape
# Out:
# (4271, 30)

# %%
len(dados)
# Out:
# 4271

# %%
dados.columns
# Out:
# Index([' ', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA?',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'COMPUTAÇÃO?', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 30 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0                                                                                                                              4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %%
dados.describe()
# Out:
#                           IDADE  MUDOU DE ESTADO?      GESTOR?        SALARIO
# count  4271.000000  4197.000000       4171.000000  3694.000000    3694.000000
# mean   2135.000000    31.169168          0.806281     0.193016   10305.310774
# std    1233.075829     6.902803          0.395258     0.394719   17644.336517
# min       0.000000    18.000000          0.000000     0.000000    1000.000000
# 25%    1067.500000    26.000000          1.000000     0.000000    5000.000000
# 50%    2135.000000    30.000000          1.000000     0.000000    7000.000000
# 75%    3202.500000    35.000000          1.000000     0.000000   14000.000000
# max    4270.000000    54.000000          1.000000     1.000000  488710.000000

# %%
dados.columns
# Out:
# Index([' ', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'PREJUDICA?',
#        'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA',
#        'UF ONDE MORA', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?',
#        'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'COMPUTAÇÃO?', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados['GENERO']
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
dados[dados['GENERO']=='Feminino']
# Out:
#                                           ID  IDADE FAIXA IDADE    GENERO  \
# 4        4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5        5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7        7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 9        9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+  Feminino
# 10      10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29  Feminino
# ...    ...                               ...    ...         ...       ...
# 4248  4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29  Feminino
# 4251  4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
# 4258  4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29  Feminino
# 4259  4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29  Feminino
# 4267  4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[dados['GENERO']=='Masculino']
# Out:
#                                           ID  IDADE FAIXA IDADE     GENERO  \
# 0        0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1        1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2        2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3        3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 6        6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# ...    ...                               ...    ...         ...        ...
# 4265  4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29  Masculino
# 4266  4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4268  4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
# ...

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#                                           ID  IDADE FAIXA IDADE  \
# 562    562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528  1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913  1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925  1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554  2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090  3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357  3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493  3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610  3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171  4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200  4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227  4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# ...

# %%
dados[dados['IDADE']>=30]
# Out:
#                                           ID  IDADE FAIXA IDADE     GENERO  \
# 0        0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1        1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2        2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 4        4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
# 5        5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34   Feminino
# ...    ...                               ...    ...         ...        ...
# 4260  4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4261  4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34  Masculino
# 4262  4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
# 4264  4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39  Masculino
# 4267  4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34   Feminino
#
# ...

# %%
dados[(dados['IDADE'] > 30) & (dados['GENERO'] == 'Feminino')]
# Out:
#                                           ID  IDADE FAIXA IDADE    GENERO  \
# 4        4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49  Feminino
# 5        5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34  Feminino
# 7        7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34  Feminino
# 14      14  zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39  Feminino
# 23      23  zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49  Feminino
# ...    ...                               ...    ...         ...       ...
# 4214  4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44  Feminino
# 4221  4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34  Feminino
# 4240  4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39  Feminino
# 4247  4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34  Feminino
# 4251  4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA                   PCD  \
# ...
